# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # A digit data set
# [Scikit-learn](https://scikit-learn.org/) comes with a dataset of handwritten digits. [Link](https://scikit-learn.org/stable/datasets/toy_dataset.html#digits-dataset)

# %%
from sklearn.datasets import load_digits
digits=load_digits()

plt.matshow(digits.images[0], cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
digits.data[0]
# Out:
# array([ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.,  0.,  0., 13., 15., 10.,
#        15.,  5.,  0.,  0.,  3., 15.,  2.,  0., 11.,  8.,  0.,  0.,  4.,
#        12.,  0.,  0.,  8.,  8.,  0.,  0.,  5.,  8.,  0.,  0.,  9.,  8.,
#         0.,  0.,  4., 11.,  0.,  1., 12.,  7.,  0.,  0.,  2., 14.,  5.,
#        10., 12.,  0.,  0.,  0.,  0.,  6., 13., 10.,  0.,  0.,  0.])

# %%
X=digits.data
C=digits.target
X.shape
# Out:
# (1797, 64)

# %%
#Pick out the first 100 images

X=X[0:100,:]
C=C[0:100]

X=X.T
X.shape
# Out:
# (64, 100)

# %%
plt.figure()
plt.axis()
plt.scatter(X[1,:], X[2,:], c=C, cmap='tab10')
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# compute the eigenvalues and eigenvectors
A=X@X.T
l,v =np.linalg.eig(A)

# %%
u1=v[:,0] 
u2=v[:,1]
u3=v[:,2]

# %%
y1=u1@X
y2=u2@X
y3=u3@X

# %%
plt.figure()
plt.scatter(y1, np.zeros_like(y1), c=C, cmap='tab10')
plt.colorbar()
plt.title('1D-projection')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, '1D-projection')

# %%
plt.figure()
plt.scatter(y1, y2, c=C, cmap='tab10')
plt.colorbar()
plt.title('2D-projection')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, '2D-projection')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plot=ax.scatter(y1,y2, y3, c=C, cmap='tab10')
ax.set_title('3D-projection')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 0.92, '3D-projection')
