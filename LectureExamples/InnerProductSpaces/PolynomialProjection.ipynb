# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
e=np.exp(1)

c0=4*e-10
c1=18-6*e
print(c0,c1)
# Out:
# 0.8731273138361804 1.6903090292457286

# %%
t=np.linspace(0,1)
pt= c0+c1*t
plt.plot(t, np.exp(t), t, pt)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...

# %%
A= np.array([[1, 1/2],[1/2, 1/3]])
b = np.array([np.exp(1)-1, 1])
c=np.linalg.solve(A,b)
print(c)
# Out:
# [0.87312731 1.69030903]
