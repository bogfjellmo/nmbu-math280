# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
u=np.array([1,1])
v=np.array([0,1])

a=np.cos(1)
b=np.sin(1)

# %%
P=np.stack((u,v)).T
C=np.array([[a,-b],[b,a]])

A=P@C@np.linalg.inv(P)
print(A)
# Out:
# [[ 1.38177329 -0.84147098]
#  [ 1.68294197 -0.30116868]]

# %%
np.linalg.eig(A)
# Out:
# (array([0.54030231+0.84147098j, 0.54030231-0.84147098j]),
#  array([[0.40824829+0.40824829j, 0.40824829-0.40824829j],
#         [0.81649658+0.j        , 0.81649658-0.j        ]]))

# %%
x0=np.array([1,0])
x=x0

# %%
plt.plot(x0[0], x0[1], 'o')
plt.xlim(-2.1,2.1)
plt.ylim(-2.1,2.1)
# Out:
# <img src="data:image/png;base64,..." width="639.6">
# (-2.1, 2.1)

# %%
x=A@x
plt.plot(x[0],x[1], 'o')
